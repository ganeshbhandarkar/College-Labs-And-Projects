# %%
import pygame
import math
from queue import PriorityQueue

SIZE = 800 #Window is going to be a square so we only need one variable for both Length and Width
WIN = pygame.display.set_mode((SIZE, SIZE)) #Setting Window Size
pygame.display.set_caption("A* Pathfinding Algorithm Visualizer") #Window Title

#Defining RGB Color Codes for our Cells
#THe Color of the cell will let us know what kind of cell/what attributes a cell has
BLACK = (0 , 0, 0) #Barrier
WHITE = (255, 255, 255) #Empty
GRAY = (128, 128, 128) #Grid Lines
RED = (255, 0 , 0) #Closed
GREEN = (0, 255, 0) #Open
ORANGE = (255, 165, 0) #Start
PURPLE = (128, 0 , 128) #End
TURQUOISE = (64, 224, 208) #Path

class Cell:
    def __init__(self, row, col, size, total_rows):
        self.row = row
        self.col = col
        self.x = row * size
        self.y = col * size
        self.color = WHITE
        self.neighbors = []
        self.size = size
        self.total_rows = total_rows

    #Gets the position of the cell
    def get_pos(self):
        return self.row, self.col
    
    #Methods that check the type of cell
    def is_closed(self):
        return self.color == RED
    
    def is_open(self):
        return self.color == GREEN
    
    def is_barrier(self):
        return self.color == BLACK
    
    def is_start(self):
        return self.color == ORANGE

    def is_end(self):
        return self.color == PURPLE

    #Methods that set/make cells 
    def make_closed(self):
        self.color = RED
    
    def make_open(self):
        self.color = GREEN
    
    def make_barrier(self):
        self.color = BLACK
    
    def make_start(self):
        self.color = ORANGE

    def make_end(self):
        self.color = PURPLE
    
    def make_path(self):
        self.color = TURQUOISE

    #Resets cell back to empty/white
    def reset(self):
        self.color = WHITE

    #Draws Cell
    def draw(self, win):
        pygame.draw.rect(win, self.color, (self.x, self.y, self.size, self.size))

    #Checks and updates neighboring Cells
    def update_neighbors(self, grid):
        self.neighbors = []

        #DOWN
        if self.row < self.total_rows - 1 and not grid[self.row + 1][self.col].is_barrier():
            self.neighbors.append(grid[self.row + 1][self.col])

        #UP
        if self.row > 0 and not grid[self.row - 1][self.col].is_barrier():
            self.neighbors.append(grid[self.row - 1][self.col])
        
        #RIGHT
        if self.col < self.total_rows - 1 and not grid[self.row][self.col + 1].is_barrier():
            self.neighbors.append(grid[self.row][self.col + 1])

        #LEFT
        if self.row > 0 and not grid[self.row][self.col - 1].is_barrier():
            self.neighbors.append(grid[self.row][self.col - 1])

    def __lt__(self, other):
        return False

#Defining our heuristic to calculate the distance between two points (p1 and p2)
def h(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    return abs(x1 - x2) + abs(y1 - y2)

#Reconstructs shortest path between start and end to draw
def reconstruct_path(came_from, current, draw):
    while current in came_from:
        current = came_from[current]
        current.make_path()
        draw()

#Algorithm Logic
def algorithm(draw, grid, start, end):
    count = 0
    open_set = PriorityQueue()
    open_set.put((0, count, start))
    came_from = {}

    g_score = {cell: float("inf") for row in grid for cell in row}
    g_score[start] = 0
    f_score = {cell: float("inf") for row in grid for cell in row}
    f_score[start] = h(start.get_pos(), end.get_pos())

    open_set_hash = {start}

    while not open_set.empty():
        #Allows user to quit program while algorithm is running
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
        
        current = open_set.get()[2]
        open_set_hash.remove(current)

        #Makes path if current cell is the end cell
        if current == end:
            reconstruct_path(came_from, end, draw)
            end.make_end()
            return True

        for neighbor in current.neighbors:
            temp_g_score = g_score[current] + 1

            if temp_g_score < g_score[neighbor]:
                came_from[neighbor] = current
                g_score[neighbor] = temp_g_score
                f_score[neighbor] = temp_g_score + h(neighbor.get_pos(), end.get_pos())
                if neighbor not in open_set_hash:
                    count += 1
                    open_set.put((f_score[neighbor], count, neighbor))
                    open_set_hash.add(neighbor)
                    neighbor.make_open()

        draw()

        if current != start:
            current.make_closed()

    return False        

#Makes grid of cells
def make_grid(rows, size):
    grid = []
    gap = size // rows
    for i in range(rows):
        grid.append([])
        for j in range(rows):
            cell = Cell(i , j, gap, rows)
            grid[i].append(cell)

    return grid

#Draws the grid lines onto the Window
def draw_grid(win, rows, size):
    gap = size // rows
    #For loop draws vertical lines
    for i in range(rows):
        pygame.draw.line(win, GRAY, (0, i * gap), (size, i * gap))
        #Draws horizontal lines
        for j in range(rows):
            pygame.draw.line(win, GRAY, (j * gap, 0), (j * gap, size))

def draw(win, grid, rows, size):
    win.fill(WHITE)

    for row in grid:
        for cell in row:
            cell.draw(win)
    
    draw_grid(win, rows, size)
    pygame.display.update()

def get_clicked_pos(pos, rows, size):
    gap = size // rows
    y, x = pos

    row = y // gap
    col = x // gap
    return row, col

#MAIN LOOP
def main(win, size):
    ROWS = 50
    grid = make_grid(ROWS, size)

    #Start/End Cells
    start_cell = None
    end_cell = None

    run = True

    #Main loop
    while run:
        draw(win, grid, ROWS, size)
        #Checks for different types of events that may happen
        for event in pygame.event.get():
            #Quit Event
            if event.type == pygame.QUIT:
                run = False

            #Left Mouse Click
            if pygame.mouse.get_pressed()[0]:
                pos = pygame.mouse.get_pos()
                row, col = get_clicked_pos(pos, ROWS, size)
                cell = grid[row][col]

                #If Start cell does not exist, make it
                if not start_cell and cell != end_cell:
                    start_cell = cell
                    start_cell.make_start()

                #If End cell does not exist, make it
                elif not end_cell and cell != start_cell:
                    end_cell = cell
                    end_cell.make_end()

                #make barrier cells
                elif cell != end_cell and cell != start_cell:
                    cell.make_barrier()

            #Right Mouse Click/Erase
            elif pygame.mouse.get_pressed()[2]:
                pos = pygame.mouse.get_pos()
                row, col = get_clicked_pos(pos, ROWS, size)
                cell = grid[row][col]
                cell.reset()

                if cell == start_cell:
                    start_cell = None
                elif cell == end_cell:
                    end_cell = None

            #SPACEBAR starts the pathfinding algorithm
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_SPACE and start_cell and end_cell:
                    for row in grid:
                        for cell in row:
                            cell.update_neighbors(grid)

                    algorithm(lambda: draw(win, grid, ROWS, size), grid, start_cell, end_cell)

    pygame.quit()
main(WIN, SIZE)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import math
import heapq
import pygame
import time

# TODO
# Add Popup windows/menus
# add options to pre-genterate a maze for the user
# resize window to add more nodes

# tuples for RGB values of the screen and different node states. subject to change while searching for best clarity
# white for the default nodes
# Grey for the walls or obstacles
# black for node margins
# Orange for nodes in the open set
# green for start node
# red for end node
# blue for the closed set
# yellow for the best path
NODE_COLOUR = (255, 255, 255)
WALL_COLOUR = (47,79,79)
MARGIN_COLOUR = (0,0,0)
OPEN_COLOUR = (255,178,102)
START_COLOUR = (0, 255, 0)
CLOSED_COLOUR = (82, 191, 255)
END_COLOUR = (213, 50, 80)
BEST_PATH_COLOUR = (243, 255, 82)

WIDTH = 20
HEIGHT = 20
MARGIN = 2

SCREEN_SIZE = (883, 883)

# start, end and current nodes for referencing 
start = None
current = None
end = None

# open and closed set. Open is a min heap using heapq
# closed is regular list
open = []
closed = []
# initialize empty grid
grid = []
# boolean to check if the program has already been run,
#  if it has, will reset only certain nodes to be rerun
rerun = False
# boolean to check if the program has been ended
done = False

# node class
class Node:
    # initialize node attributes
    def __init__(self, row, col, width, height):
        self.row = row
        self.col = col
        self.x = row * width
        self.y = col * width
        self.width = width
        self.height = height
        self.colour = NODE_COLOUR
        self.parent = None
        self.gcost = math.inf
        self.hcost = 0
        self.fcost = 0
    # return position of self. grid[i][i].getMyPosition
    def getMyPosition(self):
        return self.row, self.col
    # node draws itself
    def draw(self, display):
        pygame.draw.rect(display, self.colour,
        [(MARGIN + WIDTH) * self.col + MARGIN,
         (MARGIN + HEIGHT) * self.row + MARGIN, WIDTH, HEIGHT])
        pygame.display.update()
    # used when Python compares one node against another in a heap
    def __lt__(self, other):
        # if self.fcost == other.fcost:
        #     return self.hcost > other.hcost
        return self.fcost < other.fcost
    # get neighbors of self on provided grid
    #TODO enable diagonal movement?
    def getNeighbors(self, grid):
        directions = [[1, 0], [0, 1], [-1, 0], [0, -1]]
        result = []
        for direction in directions:
            newRow = (self.row + direction[0])
            newCol = (self.col + direction[1])
            if newRow > -1 and newCol > -1 and newRow < 40 and newCol < 40:
                neighbor = grid[newRow][newCol]
                if neighbor.isWall() == False:
                    result.append(neighbor)
        # result = [item for item in result if item.col > -1 and item.row > -1]
        return result
    # set of methods to change Node colour based on node type
    def makeStart(self):
        self.colour = START_COLOUR
    def makeEnd(self):
        self.colour = END_COLOUR
    def makeWall(self):
        self.colour = WALL_COLOUR
    def makeOpen(self):
        self.colour = OPEN_COLOUR
    def makeClosed(self):
        self.colour = CLOSED_COLOUR
    def makeBest(self):
        self.colour = BEST_PATH_COLOUR
    # set of methods to chek if the node is in a particular state
    def isStart(self):
        return self.colour == START_COLOUR
    def isEnd(self):
        return self.colour == END_COLOUR
    def isWall(self):
        return self.colour == WALL_COLOUR
    def isOpen(self):
        return self.colour == OPEN_COLOUR
    def isClosed(self):
        return self.colour == CLOSED_COLOUR
    def isBest(self):
        return self.colour == BEST_PATH_COLOUR
    #reset node to default white
    def reset(self):
        self.colour = NODE_COLOUR

# get position of node at mouse position
def getPosition():
    position = pygame.mouse.get_pos()
    column = position[0] // (WIDTH + MARGIN)
    row = position[1] // (HEIGHT + MARGIN)
    coords = (row, column)
    return coords

# set of action to take on mouse LEFT click
# checks to see if node is start or end to allow replacing of them
# then turns clicked nodes into walls
def placeWalls(start, end, grid):
    row, col = getPosition()
    if grid[row][col].isStart():
        start = None
        grid[row][col].makeWall()
    elif grid[row][col].isEnd():
        end = None
        grid[row][col].makeWall()
    else:
        grid[row][col].makeWall()

# set of action to take on mouse RIGHT click
# checks to see if node is start or end to allow replacing of them
# then resets clicked node
def resetNode(start, end, grid):
    row, col = getPosition()
    if grid[row][col].isStart():
        start = None
        grid[row][col].reset()
    elif grid[row][col].isEnd():
        end = None
        grid[row][col].reset()
    else:
        grid[row][col].reset()

# draw nodes on screen and draw colors based on class method returns
def draw():
    for row in range(40):
        for column in range(40):
            colour = NODE_COLOUR
            if grid[row][column].isWall():
                colour = WALL_COLOUR
            if grid[row][column].isStart():
                colour = START_COLOUR
            if grid[row][column].isEnd():
                colour = END_COLOUR
            if grid[row][column].isOpen():
                colour = OPEN_COLOUR
            if grid[row][column].isClosed():
                colour = CLOSED_COLOUR
            if grid[row][column].isBest():
                colour = BEST_PATH_COLOUR
            pygame.draw.rect(
                display, colour,
                [(MARGIN + WIDTH) * column + MARGIN,
                 (MARGIN + HEIGHT) * row + MARGIN, WIDTH, HEIGHT])

# starting from end node follow parents to start node for best path
def drawShortestPath(grid, end):
    last = end
    for x in range(40):
        for y in range(40):
            if last.parent == start:
                break
            lastx, lasty = last.getMyPosition()
            cameFrom = grid[lastx][lasty].parent
            cfx, cfy = cameFrom.getMyPosition()
            if not grid[cfx][cfy].isStart():
                grid[cfx][cfy].makeBest()
            grid[cfx][cfx].draw(display)
            last = cameFrom

# reset the grid completely
def resetGrid(grid):
    for x in range(40):
        for y in range(40):
            grid[x][y].reset()
            grid[x][y].parent = None
            grid[x][y].hcost = 0
            grid[x][y].gcost = math.inf
            grid[x][y].fcost = 0

# reset the grid keeping the walls, start and end nodes
def resetForReRun(grid):
    for x in range(40):
        for y in range(40):
            if grid[x][y].isStart() or grid[x][y].isEnd() or grid[x][y].isWall():
                grid[x][y].parent = None
                grid[x][y].hcost = 0
                grid[x][y].gcost = math.inf
                grid[x][y].fcost = 0
            else:
                grid[x][y].reset()
                grid[x][y].parent = None
                grid[x][y].hcost = 0
                grid[x][y].gcost = math.inf
                grid[x][y].fcost = 0

# get the "manhattan distance" between two coordinates
# the absolute value of value 1 in the first coords 
# subtracted by the first value in the other 
# then the same for the second values
#then returning the sum of the resulting values
def getManhattanDistance(pt1, pt2):
    distance = 0
    for i in range(len(pt1)):
        distance += abs(pt1[i] - pt2[i])
    return distance

# starting from start node, evaluate neighboring nodes to 
# find best path to end node
#* algorithm is A*. This algorithm knows the 
#* location of the end node and makes its decision with another 
#* function that gets a heuristic for the distance between the 
#* current node and the end node. gives each node it discovers
#* a value of the distance from the start to the current node plus the heuristic
#* then, it chooses the current cheapest node, repeating untill end is found

def algorithm(grid, current, start, end):
    if not start:
        print("select a start node")
        return
    elif not end:
        print("select an end node")
        return
    start.gcost = 0
    start.fcost = getManhattanDistance(start.getMyPosition(), end.getMyPosition())
    heapq.heappush(open, start)
    if open:
        while open[0] != end:
            # get the best node from open set
            # and make that current node
            current = heapq.heappop(open)
            if not current.isStart() and not current.isEnd():
                current.makeClosed()
                current.draw(display)
            closed.append(current)
            neighbors = current.getNeighbors(grid)
            for neighbor in neighbors:
                cost = None
                cost = current.gcost + 10
                if neighbor in open and cost < neighbor.gcost:
                    neighbor.reset()
                    i = open.index(neighbor)
                    open[i] = open[-1]
                    open.pop()
                    heapq.heapify(open)
                if neighbor in closed and cost < neighbor.gcost:
                    closed.remove(neighbor)
                    neighbor.reset()
                if neighbor not in open and neighbor not in closed:
                    neighbor.gcost = cost        
                    neighbor.hcost = getManhattanDistance(neighbor.getMyPosition(), end.getMyPosition())
                    neighbor.fcost = neighbor.gcost + neighbor.hcost 
                    neighbor.parent = current
                    if not neighbor.isEnd():
                        neighbor.makeOpen()
                        neighbor.draw(display)
                    print("Neighbors for current. FCOST: ", neighbor.fcost)
                    heapq.heappush(open, neighbor) 
            if not open:
                    print("connot find end node")
                    return                
        drawShortestPath(grid, end)     
        print("FOUND YOU")  

# initialize the grid with Node objects
for x in range(40):
    grid.append([])
    for y in range(40):
        node = Node(x, y, WIDTH, HEIGHT)
        grid[x].append(node)

# init function for pygame
pygame.init()

# create display and set size. Currently using
#  883 x 883 as it fits 40 x 40 20 x 20 px squares
display = pygame.display.set_mode((883, 883))

# set caption of the display
pygame.display.set_caption('Pathfinding Visualizer - S for Start node - E for End - Left Click for wall - Right Click for reset selected - R reset all - SPACE to run')
clock = pygame.time.Clock()

# check for inputs and execute tasks based on said inputs
while not done:
    clock.tick(60)
    for event in pygame.event.get():
        # exit game 
        if event.type == pygame.QUIT:
            done = True
        # place walls
        elif pygame.mouse.get_pressed()[0]:
            placeWalls(start, end, grid)

        # reset selected node
        elif pygame.mouse.get_pressed()[2]:
            resetNode(start, end, grid)

        # keypress events
        elif event.type == pygame.KEYDOWN:
            # check if the start node has been placed if not, 
            # set node to star if it has been placed, remove 
            # the current node and place it in new location.
            if event.key == pygame.K_s:    
                row, col = getPosition()
                if not start:   
                    start = grid[row][col]
                    grid[row][col].makeStart()                 
                else:
                    for x in range(40):
                        for y in range(40):
                            if grid[x][y].isStart():
                                start = None
                                grid[x][y].reset()
                    if grid[row][col].isEnd():
                        end = None
                        start = grid[row][col]
                        grid[row][col].makeStart()
                    else:
                        start = grid[row][col]
                        grid[row][col].makeStart()
            elif event.key == pygame.K_e:
                row, col = getPosition()
                if not end:
                    end = grid[row][col]
                    grid[row][col].makeEnd()
                elif end:
                    for x in range(40):
                        for y in range(40):
                            if grid[x][y].isEnd():
                                end = None
                                grid[x][y].reset()
                            elif grid[row][col].isStart():
                                start = None
                                end = grid[row][col]
                                grid[row][col].makeEnd()
                            else:
                                end = grid[row][col]
                                grid[row][col].makeEnd()
            elif event.key == pygame.K_r:
                start = None
                end = None
                current = None
                closed = []
                open = []
                resetGrid(grid)
                rerun = False
            elif event.key == pygame.K_SPACE:
                if not rerun:
                    algorithm(grid, current, start, end)
                    rerun = True
                else:
                    current = None
                    closed = []
                    open = []
                    resetForReRun(grid)
                    draw()
                    pygame.display.update()
                    algorithm(grid, current, start, end)
    display.fill(MARGIN_COLOUR)
    # draw
    draw()
    pygame.display.update()

#quit fuction for pygame
pygame.quit()
# Out:
# select a start node
# select a start node
# select a start node
# select a start node
# Neighbors for current. FCOST:  62
# Neighbors for current. FCOST:  62
# Neighbors for current. FCOST:  64
# Neighbors for current. FCOST:  64
# Neighbors for current. FCOST:  71
# Neighbors for current. FCOST:  71
# Neighbors for current. FCOST:  73
# Neighbors for current. FCOST:  71
# Neighbors for current. FCOST:  73
# Neighbors for current. FCOST:  75
# Neighbors for current. FCOST:  75
# Neighbors for current. FCOST:  75
# Neighbors for current. FCOST:  80
# Neighbors for current. FCOST:  80
# Neighbors for current. FCOST:  82
# Neighbors for current. FCOST:  80
# Neighbors for current. FCOST:  80
# Neighbors for current. FCOST:  82
# Neighbors for current. FCOST:  84
# Neighbors for current. FCOST:  84
# Neighbors for current. FCOST:  86
# Neighbors for current. FCOST:  86
# Neighbors for current. FCOST:  86
# Neighbors for current. FCOST:  86
# Neighbors for current. FCOST:  89
# Neighbors for current. FCOST:  89
# Neighbors for current. FCOST:  89
# Neighbors for current. FCOST:  91
# Neighbors for current. FCOST:  89
# Neighbors for current. FCOST:  89
# Neighbors for current. FCOST:  91
# Neighbors for current. FCOST:  93
# Neighbors for current. FCOST:  93
# Neighbors for current. FCOST:  95
# Neighbors for current. FCOST:  95
# Neighbors for current. FCOST:  97
# Neighbors for current. FCOST:  97
# Neighbors for current. FCOST:  97
# Neighbors for current. FCOST:  97
# Neighbors for current. FCOST:  97
# Neighbors for current. FCOST:  98
# Neighbors for current. FCOST:  100
# Neighbors for current. FCOST:  98
# Neighbors for current. FCOST:  98
# Neighbors for current. FCOST:  98
# Neighbors for current. FCOST:  100
# Neighbors for current. FCOST:  98
# Neighbors for current. FCOST:  102
# Neighbors for current. FCOST:  104
# Neighbors for current. FCOST:  106
# Neighbors for current. FCOST:  106
# Neighbors for current. FCOST:  108
# Neighbors for current. FCOST:  108
# Neighbors for current. FCOST:  108
# Neighbors for current. FCOST:  108
# Neighbors for current. FCOST:  108
# Neighbors for current. FCOST:  107
# Neighbors for current. FCOST:  107
# Neighbors for current. FCOST:  109
# Neighbors for current. FCOST:  107
# Neighbors for current. FCOST:  111
# Neighbors for current. FCOST:  113
# Neighbors for current. FCOST:  115
# Neighbors for current. FCOST:  115
# Neighbors for current. FCOST:  117
# Neighbors for current. FCOST:  117
# Neighbors for current. FCOST:  116
# Neighbors for current. FCOST:  118
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  119
# Neighbors for current. FCOST:  120
# Neighbors for current. FCOST:  122
# Neighbors for current. FCOST:  124
# Neighbors for current. FCOST:  124
# Neighbors for current. FCOST:  126
# Neighbors for current. FCOST:  126
# Neighbors for current. FCOST:  127
# Neighbors for current. FCOST:  128
# Neighbors for current. FCOST:  128
# Neighbors for current. FCOST:  129
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  130
# Neighbors for current. FCOST:  131
# Neighbors for current. FCOST:  133
# Neighbors for current. FCOST:  135
# Neighbors for current. FCOST:  133
# Neighbors for current. FCOST:  135
# Neighbors for current. FCOST:  137
# Neighbors for current. FCOST:  137
# Neighbors for current. FCOST:  136
# Neighbors for current. FCOST:  138
# Neighbors for current. FCOST:  139
# Neighbors for current. FCOST:  140
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  141
# Neighbors for current. FCOST:  142
# Neighbors for current. FCOST:  144
# Neighbors for current. FCOST:  142
# Neighbors for current. FCOST:  142
# Neighbors for current. FCOST:  144
# Neighbors for current. FCOST:  146
# Neighbors for current. FCOST:  146
# Neighbors for current. FCOST:  145
# Neighbors for current. FCOST:  147
# Neighbors for current. FCOST:  148
# Neighbors for current. FCOST:  149
# Neighbors for current. FCOST:  150
# Neighbors for current. FCOST:  151
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  152
# Neighbors for current. FCOST:  153
# Neighbors for current. FCOST:  151
# Neighbors for current. FCOST:  151
# Neighbors for current. FCOST:  153
# Neighbors for current. FCOST:  155
# Neighbors for current. FCOST:  155
# Neighbors for current. FCOST:  154
# Neighbors for current. FCOST:  156
# Neighbors for current. FCOST:  157
# Neighbors for current. FCOST:  158
# Neighbors for current. FCOST:  159
# Neighbors for current. FCOST:  160
# Neighbors for current. FCOST:  161
# Neighbors for current. FCOST:  160
# Neighbors for current. FCOST:  160
# Neighbors for current. FCOST:  162
# Neighbors for current. FCOST:  160
# Neighbors for current. FCOST:  162
# Neighbors for current. FCOST:  163
# Neighbors for current. FCOST:  163
# Neighbors for current. FCOST:  163
# Neighbors for current. FCOST:  163
# Neighbors for current. FCOST:  163
# Neighbors for current. FCOST:  163
# Neighbors for current. FCOST:  164
# Neighbors for current. FCOST:  164
# Neighbors for current. FCOST:  165
# Neighbors for current. FCOST:  166
# Neighbors for current. FCOST:  167
# Neighbors for current. FCOST:  168
# Neighbors for current. FCOST:  169
# Neighbors for current. FCOST:  170
# Neighbors for current. FCOST:  171
# Neighbors for current. FCOST:  169
# Neighbors for current. FCOST:  169
# Neighbors for current. FCOST:  171
# Neighbors for current. FCOST:  169
# Neighbors for current. FCOST:  173
# Neighbors for current. FCOST:  173
# Neighbors for current. FCOST:  174
# Neighbors for current. FCOST:  174
# Neighbors for current. FCOST:  174
# Neighbors for current. FCOST:  174
# Neighbors for current. FCOST:  174
# Neighbors for current. FCOST:  175
# Neighbors for current. FCOST:  174
# Neighbors for current. FCOST:  176
# Neighbors for current. FCOST:  177
# Neighbors for current. FCOST:  178
# Neighbors for current. FCOST:  179
# Neighbors for current. FCOST:  180
# Neighbors for current. FCOST:  178
# Neighbors for current. FCOST:  178
# Neighbors for current. FCOST:  178
# Neighbors for current. FCOST:  180
# Neighbors for current. FCOST:  182
# Neighbors for current. FCOST:  182
# Neighbors for current. FCOST:  184
# Neighbors for current. FCOST:  185
# Neighbors for current. FCOST:  185
# Neighbors for current. FCOST:  185
# Neighbors for current. FCOST:  185
# Neighbors for current. FCOST:  183
# Neighbors for current. FCOST:  185
# Neighbors for current. FCOST:  186
# Neighbors for current. FCOST:  187
# Neighbors for current. FCOST:  188
# Neighbors for current. FCOST:  189
# Neighbors for current. FCOST:  187
# Neighbors for current. FCOST:  187
# Neighbors for current. FCOST:  189
# Neighbors for current. FCOST:  187
# Neighbors for current. FCOST:  187
# Neighbors for current. FCOST:  191
# Neighbors for current. FCOST:  191
# Neighbors for current. FCOST:  193
# Neighbors for current. FCOST:  192
# Neighbors for current. FCOST:  194
# Neighbors for current. FCOST:  195
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  197
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  198
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  198
# Neighbors for current. FCOST:  196
# Neighbors for current. FCOST:  200
# Neighbors for current. FCOST:  200
# Neighbors for current. FCOST:  202
# Neighbors for current. FCOST:  201
# Neighbors for current. FCOST:  203
# Neighbors for current. FCOST:  204
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  206
# Neighbors for current. FCOST:  207
# Neighbors for current. FCOST:  207
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  207
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  205
# Neighbors for current. FCOST:  207
# Neighbors for current. FCOST:  207
# Neighbors for current. FCOST:  209
# Neighbors for current. FCOST:  209
# Neighbors for current. FCOST:  211
# Neighbors for current. FCOST:  210
# Neighbors for current. FCOST:  212
# Neighbors for current. FCOST:  213
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  215
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  216
# Neighbors for current. FCOST:  216
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  214
# Neighbors for current. FCOST:  216
# Neighbors for current. FCOST:  218
# Neighbors for current. FCOST:  218
# Neighbors for current. FCOST:  218
# Neighbors for current. FCOST:  220
# Neighbors for current. FCOST:  219
# Neighbors for current. FCOST:  219
# Neighbors for current. FCOST:  222
# Neighbors for current. FCOST:  221
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  224
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  225
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  225
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  223
# Neighbors for current. FCOST:  225
# Neighbors for current. FCOST:  227
# Neighbors for current. FCOST:  227
# Neighbors for current. FCOST:  229
# Neighbors for current. FCOST:  228
# Neighbors for current. FCOST:  228
# Neighbors for current. FCOST:  230
# Neighbors for current. FCOST:  228
# Neighbors for current. FCOST:  231
# Neighbors for current. FCOST:  230
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  233
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  234
# Neighbors for current. FCOST:  234
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  234
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  232
# Neighbors for current. FCOST:  236
# Neighbors for current. FCOST:  236
# Neighbors for current. FCOST:  238
# Neighbors for current. FCOST:  237
# Neighbors for current. FCOST:  237
# Neighbors for current. FCOST:  239
# Neighbors for current. FCOST:  237
# Neighbors for current. FCOST:  237
# Neighbors for current. FCOST:  240
# Neighbors for current. FCOST:  239
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  242
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  243
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  243
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  241
# Neighbors for current. FCOST:  243
# Neighbors for current. FCOST:  245
# Neighbors for current. FCOST:  245
# Neighbors for current. FCOST:  245
# Neighbors for current. FCOST:  247
# Neighbors for current. FCOST:  246
# Neighbors for current. FCOST:  246
# Neighbors for current. FCOST:  246
# Neighbors for current. FCOST:  246
# Neighbors for current. FCOST:  248
# Neighbors for current. FCOST:  246
# Neighbors for current. FCOST:  249
# Neighbors for current. FCOST:  248
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  251
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  252
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  252
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  252
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  252
# Neighbors for current. FCOST:  250
# Neighbors for current. FCOST:  254
# Neighbors for current. FCOST:  254
# Neighbors for current. FCOST:  254
# Neighbors for current. FCOST:  256
# Neighbors for current. FCOST:  255
# Neighbors for current. FCOST:  255
# Neighbors for current. FCOST:  255
# Neighbors for current. FCOST:  255
# Neighbors for current. FCOST:  255
# Neighbors for current. FCOST:  255
# Neighbors for current. FCOST:  257
# Neighbors for current. FCOST:  258
# Neighbors for current. FCOST:  257
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  260
# Neighbors for current. FCOST:  261
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  261
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  261
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  259
# Neighbors for current. FCOST:  261
# Neighbors for current. FCOST:  263
# Neighbors for current. FCOST:  263
# Neighbors for current. FCOST:  263
# Neighbors for current. FCOST:  265
# Neighbors for current. FCOST:  265
# Neighbors for current. FCOST:  264
# Neighbors for current. FCOST:  264
# Neighbors for current. FCOST:  264
# Neighbors for current. FCOST:  266
# Neighbors for current. FCOST:  264
# Neighbors for current. FCOST:  266
# Neighbors for current. FCOST:  267
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  266
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  269
# Neighbors for current. FCOST:  270
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  270
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  270
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  268
# Neighbors for current. FCOST:  270
# Neighbors for current. FCOST:  272
# Neighbors for current. FCOST:  272
# Neighbors for current. FCOST:  272
# Neighbors for current. FCOST:  272
# Neighbors for current. FCOST:  274
# Neighbors for current. FCOST:  274
# Neighbors for current. FCOST:  273
# Neighbors for current. FCOST:  273
# Neighbors for current. FCOST:  273
# Neighbors for current. FCOST:  273
# Neighbors for current. FCOST:  276
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  275
# Neighbors for current. FCOST:  275
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  278
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  279
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  279
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  279
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  279
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  277
# Neighbors for current. FCOST:  281
# Neighbors for current. FCOST:  281
# Neighbors for current. FCOST:  281
# Neighbors for current. FCOST:  281
# Neighbors for current. FCOST:  283
# Neighbors for current. FCOST:  283
# Neighbors for current. FCOST:  283
# Neighbors for current. FCOST:  282
# Neighbors for current. FCOST:  282
# Neighbors for current. FCOST:  282
# Neighbors for current. FCOST:  282
# Neighbors for current. FCOST:  285
# Neighbors for current. FCOST:  285
# Neighbors for current. FCOST:  284
# Neighbors for current. FCOST:  284
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  287
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  288
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  288
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  288
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  288
# Neighbors for current. FCOST:  286
# Neighbors for current. FCOST:  290
# Neighbors for current. FCOST:  290
# Neighbors for current. FCOST:  290
# Neighbors for current. FCOST:  290
# Neighbors for current. FCOST:  292
# Neighbors for current. FCOST:  292
# Neighbors for current. FCOST:  292
# Neighbors for current. FCOST:  291
# Neighbors for current. FCOST:  293
# Neighbors for current. FCOST:  291
# Neighbors for current. FCOST:  291
# Neighbors for current. FCOST:  294
# Neighbors for current. FCOST:  294
# Neighbors for current. FCOST:  294
# Neighbors for current. FCOST:  293
# Neighbors for current. FCOST:  293
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  296
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  297
# Neighbors for current. FCOST:  297
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  297
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  297
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  295
# Neighbors for current. FCOST:  299
# Neighbors for current. FCOST:  299
# Neighbors for current. FCOST:  299
# Neighbors for current. FCOST:  299
# Neighbors for current. FCOST:  301
# Neighbors for current. FCOST:  301
# Neighbors for current. FCOST:  301
# Neighbors for current. FCOST:  300
# Neighbors for current. FCOST:  300
# Neighbors for current. FCOST:  300
# Neighbors for current. FCOST:  303
# Neighbors for current. FCOST:  303
# Neighbors for current. FCOST:  303
# Neighbors for current. FCOST:  302
# Neighbors for current. FCOST:  302
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  302
# Neighbors for current. FCOST:  305
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  306
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  304
# Neighbors for current. FCOST:  306
# Neighbors for current. FCOST:  306
# Neighbors for current. FCOST:  306
# Neighbors for current. FCOST:  308
# Neighbors for current. FCOST:  308
# Neighbors for current. FCOST:  310
# Neighbors for current. FCOST:  310
# Neighbors for current. FCOST:  309
# Neighbors for current. FCOST:  309
# Neighbors for current. FCOST:  309
# Neighbors for current. FCOST:  312
# Neighbors for current. FCOST:  312
# Neighbors for current. FCOST:  311
# Neighbors for current. FCOST:  311
# Neighbors for current. FCOST:  311
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  314
# Neighbors for current. FCOST:  314
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  315
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  315
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  313
# Neighbors for current. FCOST:  317
# Neighbors for current. FCOST:  317
# Neighbors for current. FCOST:  317
# Neighbors for current. FCOST:  317
# Neighbors for current. FCOST:  319
# Neighbors for current. FCOST:  318
# Neighbors for current. FCOST:  318
# Neighbors for current. FCOST:  318
# Neighbors for current. FCOST:  321
# Neighbors for current. FCOST:  320
# Neighbors for current. FCOST:  320
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  320
# Neighbors for current. FCOST:  323
# Neighbors for current. FCOST:  324
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  322
# Neighbors for current. FCOST:  324
# Neighbors for current. FCOST:  326
# Neighbors for current. FCOST:  326
# Neighbors for current. FCOST:  328
# Neighbors for current. FCOST:  328
# Neighbors for current. FCOST:  328
# Neighbors for current. FCOST:  328
# Neighbors for current. FCOST:  327
# Neighbors for current. FCOST:  327
# Neighbors for current. FCOST:  327
# Neighbors for current. FCOST:  330
# Neighbors for current. FCOST:  329
# Neighbors for current. FCOST:  329
# Neighbors for current. FCOST:  329
# Neighbors for current. FCOST:  329
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  332
# Neighbors for current. FCOST:  333
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  333
# Neighbors for current. FCOST:  331
# Neighbors for current. FCOST:  335
# Neighbors for current. FCOST:  335
# Neighbors for current. FCOST:  337
# Neighbors for current. FCOST:  337
# Neighbors for current. FCOST:  336
# Neighbors for current. FCOST:  336
# Neighbors for current. FCOST:  336
# Neighbors for current. FCOST:  339
# Neighbors for current. FCOST:  339
# Neighbors for current. FCOST:  339
# Neighbors for current. FCOST:  339
# Neighbors for current. FCOST:  338
# Neighbors for current. FCOST:  338
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  338
# Neighbors for current. FCOST:  338
# Neighbors for current. FCOST:  341
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  342
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  340
# Neighbors for current. FCOST:  342
# Neighbors for current. FCOST:  344
# Neighbors for current. FCOST:  344
# Neighbors for current. FCOST:  346
# Neighbors for current. FCOST:  346
# Neighbors for current. FCOST:  345
# Neighbors for current. FCOST:  345
# Neighbors for current. FCOST:  345
# Neighbors for current. FCOST:  345
# Neighbors for current. FCOST:  348
# Neighbors for current. FCOST:  348
# Neighbors for current. FCOST:  347
# Neighbors for current. FCOST:  347
# Neighbors for current. FCOST:  347
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  347
# Neighbors for current. FCOST:  350
# Neighbors for current. FCOST:  350
# Neighbors for current. FCOST:  350
# Neighbors for current. FCOST:  350
# Neighbors for current. FCOST:  351
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  351
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  349
# Neighbors for current. FCOST:  351
# Neighbors for current. FCOST:  353
# Neighbors for current. FCOST:  353
# Neighbors for current. FCOST:  355
# Neighbors for current. FCOST:  355
# Neighbors for current. FCOST:  354
# Neighbors for current. FCOST:  354
# Neighbors for current. FCOST:  354
# Neighbors for current. FCOST:  354
# Neighbors for current. FCOST:  357
# Neighbors for current. FCOST:  357
# Neighbors for current. FCOST:  356
# Neighbors for current. FCOST:  356
# Neighbors for current. FCOST:  356
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  356
# Neighbors for current. FCOST:  356
# Neighbors for current. FCOST:  359
# Neighbors for current. FCOST:  359
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  360
# Neighbors for current. FCOST:  360
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  360
# Neighbors for current. FCOST:  358
# Neighbors for current. FCOST:  361
# Neighbors for current. FCOST:  361
# Neighbors for current. FCOST:  361
# Neighbors for current. FCOST:  362
# Neighbors for current. FCOST:  362
# Neighbors for current. FCOST:  364
# Neighbors for current. FCOST:  364
# Neighbors for current. FCOST:  363
# Neighbors for current. FCOST:  363
# Neighbors for current. FCOST:  363
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  363
# Neighbors for current. FCOST:  366
# Neighbors for current. FCOST:  366
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  365
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  368
# Neighbors for current. FCOST:  368
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  369
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  369
# Neighbors for current. FCOST:  367
# Neighbors for current. FCOST:  369
# Neighbors for current. FCOST:  370
# Neighbors for current. FCOST:  371
# Neighbors for current. FCOST:  371
# Neighbors for current. FCOST:  371
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  373
# Neighbors for current. FCOST:  373
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  372
# Neighbors for current. FCOST:  375
# Neighbors for current. FCOST:  375
# Neighbors for current. FCOST:  374
# Neighbors for current. FCOST:  374
# Neighbors for current. FCOST:  374
# Neighbors for current. FCOST:  374
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  374
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  377
# Neighbors for current. FCOST:  377
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  378
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  378
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  378
# Neighbors for current. FCOST:  376
# Neighbors for current. FCOST:  379
# Neighbors for current. FCOST:  380
# Neighbors for current. FCOST:  380
# Neighbors for current. FCOST:  380
# Neighbors for current. FCOST:  381
# Neighbors for current. FCOST:  382
# Neighbors for current. FCOST:  382
# Neighbors for current. FCOST:  382
# Neighbors for current. FCOST:  381
# Neighbors for current. FCOST:  381
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  381
# Neighbors for current. FCOST:  381
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  384
# Neighbors for current. FCOST:  384
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  383
# Neighbors for current. FCOST:  386
# Neighbors for current. FCOST:  386
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  387
# Neighbors for current. FCOST:  387
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  387
# Neighbors for current. FCOST:  387
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  387
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  387
# Neighbors for current. FCOST:  385
# Neighbors for current. FCOST:  388
# Neighbors for current. FCOST:  389
# Neighbors for current. FCOST:  389
# Neighbors for current. FCOST:  390
# Neighbors for current. FCOST:  391
# Neighbors for current. FCOST:  391
# Neighbors for current. FCOST:  391
# Neighbors for current. FCOST:  390
# Neighbors for current. FCOST:  390
# Neighbors for current. FCOST:  390
# Neighbors for current. FCOST:  390
# Neighbors for current. FCOST:  392
# Neighbors for current. FCOST:  390
# Neighbors for current. FCOST:  393
# Neighbors for current. FCOST:  393
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  392
# Neighbors for current. FCOST:  392
# Neighbors for current. FCOST:  392
# Neighbors for current. FCOST:  392
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  392
# Neighbors for current. FCOST:  395
# Neighbors for current. FCOST:  395
# Neighbors for current. FCOST:  396
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  396
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  396
# Neighbors for current. FCOST:  394
# Neighbors for current. FCOST:  397
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  398
# Neighbors for current. FCOST:  399
# Neighbors for current. FCOST:  400
# Neighbors for current. FCOST:  400
# Neighbors for current. FCOST:  399
# Neighbors for current. FCOST:  399
# Neighbors for current. FCOST:  399
# Neighbors for current. FCOST:  399
# Neighbors for current. FCOST:  401
# Neighbors for current. FCOST:  399
# Neighbors for current. FCOST:  402
# Neighbors for current. FCOST:  402
# Neighbors for current. FCOST:  402
# Neighbors for current. FCOST:  401
# Neighbors for current. FCOST:  401
# Neighbors for current. FCOST:  401
# Neighbors for current. FCOST:  401
# Neighbors for current. FCOST:  401
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  404
# Neighbors for current. FCOST:  404
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  405
# Neighbors for current. FCOST:  403
# Neighbors for current. FCOST:  405
# Neighbors for current. FCOST:  405
# Neighbors for current. FCOST:  405
# Neighbors for current. FCOST:  406
# Neighbors for current. FCOST:  407
# Neighbors for current. FCOST:  407
# Neighbors for current. FCOST:  408
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  409
# Neighbors for current. FCOST:  408
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  408
# Neighbors for current. FCOST:  408
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  408
# Neighbors for current. FCOST:  411
# Neighbors for current. FCOST:  411
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  410
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  413
# Neighbors for current. FCOST:  413
# Neighbors for current. FCOST:  413
# Neighbors for current. FCOST:  414
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  414
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  412
# Neighbors for current. FCOST:  414
# Neighbors for current. FCOST:  415
# Neighbors for current. FCOST:  416
# Neighbors for current. FCOST:  416
# Neighbors for current. FCOST:  417
# Neighbors for current. FCOST:  418
# Neighbors for current. FCOST:  418
# Neighbors for current. FCOST:  417
# Neighbors for current. FCOST:  417
# Neighbors for current. FCOST:  419
# Neighbors for current. FCOST:  417
# Neighbors for current. FCOST:  417
# Neighbors for current. FCOST:  419
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  420
# Neighbors for current. FCOST:  419
# Neighbors for current. FCOST:  419
# Neighbors for current. FCOST:  419
# Neighbors for current. FCOST:  419
# Neighbors for current. FCOST:  421
# Neighbors for current. FCOST:  422
# Neighbors for current. FCOST:  422
# Neighbors for current. FCOST:  421
# Neighbors for current. FCOST:  423
# Neighbors for current. FCOST:  423
# Neighbors for current. FCOST:  421
# Neighbors for current. FCOST:  421
# Neighbors for current. FCOST:  423
# Neighbors for current. FCOST:  422
# Neighbors for current. FCOST:  424
# Neighbors for current. FCOST:  425
# Neighbors for current. FCOST:  425
# Neighbors for current. FCOST:  426
# Neighbors for current. FCOST:  427
# Neighbors for current. FCOST:  427
# Neighbors for current. FCOST:  428
# Neighbors for current. FCOST:  426
# Neighbors for current. FCOST:  426
# Neighbors for current. FCOST:  426
# Neighbors for current. FCOST:  426
# Neighbors for current. FCOST:  428
# Neighbors for current. FCOST:  429
# Neighbors for current. FCOST:  429
# Neighbors for current. FCOST:  428
# Neighbors for current. FCOST:  428
# Neighbors for current. FCOST:  430
# Neighbors for current. FCOST:  428
# Neighbors for current. FCOST:  430
# Neighbors for current. FCOST:  428
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  431
# Neighbors for current. FCOST:  432
# Neighbors for current. FCOST:  430
# Neighbors for current. FCOST:  432
# Neighbors for current. FCOST:  432
# Neighbors for current. FCOST:  430
# Neighbors for current. FCOST:  432
# Neighbors for current. FCOST:  430
# Neighbors for current. FCOST:  433
# Neighbors for current. FCOST:  433
# Neighbors for current. FCOST:  434
# Neighbors for current. FCOST:  432
# Neighbors for current. FCOST:  434
# Neighbors for current. FCOST:  435
# Neighbors for current. FCOST:  436
# Neighbors for current. FCOST:  436
# Neighbors for current. FCOST:  435
# Neighbors for current. FCOST:  435
# Neighbors for current. FCOST:  437
# Neighbors for current. FCOST:  435
# Neighbors for current. FCOST:  435
# Neighbors for current. FCOST:  437
# Neighbors for current. FCOST:  438
# Neighbors for current. FCOST:  438
# Neighbors for current. FCOST:  439
# Neighbors for current. FCOST:  437
# Neighbors for current. FCOST:  439
# Neighbors for current. FCOST:  437
# Neighbors for current. FCOST:  437
# Neighbors for current. FCOST:  437
# Neighbors for current. FCOST:  440
# Neighbors for current. FCOST:  440
# Neighbors for current. FCOST:  441
# Neighbors for current. FCOST:  439
# Neighbors for current. FCOST:  439
# Neighbors for current. FCOST:  439
# Neighbors for current. FCOST:  439
# Neighbors for current. FCOST:  441
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  441
# Neighbors for current. FCOST:  443
# Neighbors for current. FCOST:  443
# Neighbors for current. FCOST:  443
# Neighbors for current. FCOST:  443
# Neighbors for current. FCOST:  442
# Neighbors for current. FCOST:  444
# Neighbors for current. FCOST:  445
# Neighbors for current. FCOST:  445
# Neighbors for current. FCOST:  444
# Neighbors for current. FCOST:  444
# Neighbors for current. FCOST:  446
# Neighbors for current. FCOST:  446
# Neighbors for current. FCOST:  444
# Neighbors for current. FCOST:  444
# Neighbors for current. FCOST:  444
# Neighbors for current. FCOST:  447
# Neighbors for current. FCOST:  447
# Neighbors for current. FCOST:  446
# Neighbors for current. FCOST:  446
# Neighbors for current. FCOST:  446
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  446
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  449
# Neighbors for current. FCOST:  449
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  450
# Neighbors for current. FCOST:  448
# Neighbors for current. FCOST:  450
# Neighbors for current. FCOST:  450
# Neighbors for current. FCOST:  450
# Neighbors for current. FCOST:  451
# Neighbors for current. FCOST:  451
# Neighbors for current. FCOST:  452
# Neighbors for current. FCOST:  452
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  454
# Neighbors for current. FCOST:  454
# Neighbors for current. FCOST:  452
# Neighbors for current. FCOST:  454
# Neighbors for current. FCOST:  454
# Neighbors for current. FCOST:  454
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  455
# Neighbors for current. FCOST:  455
# Neighbors for current. FCOST:  453
# Neighbors for current. FCOST:  456
# Neighbors for current. FCOST:  456
# Neighbors for current. FCOST:  455
# Neighbors for current. FCOST:  455
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  455
# Neighbors for current. FCOST:  455
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  458
# Neighbors for current. FCOST:  458
# Neighbors for current. FCOST:  459
# Neighbors for current. FCOST:  459
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  459
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  459
# Neighbors for current. FCOST:  457
# Neighbors for current. FCOST:  459
# Neighbors for current. FCOST:  459
# Neighbors for current. FCOST:  460
# Neighbors for current. FCOST:  460
# Neighbors for current. FCOST:  461
# Neighbors for current. FCOST:  461
# Neighbors for current. FCOST:  462
# Neighbors for current. FCOST:  462
# Neighbors for current. FCOST:  463
# Neighbors for current. FCOST:  463
# Neighbors for current. FCOST:  462
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  462
# Neighbors for current. FCOST:  462
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  462
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  465
# Neighbors for current. FCOST:  465
# Neighbors for current. FCOST:  465
# Neighbors for current. FCOST:  465
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  464
# Neighbors for current. FCOST:  467
# Neighbors for current. FCOST:  468
# Neighbors for current. FCOST:  468
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  468
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  468
# Neighbors for current. FCOST:  466
# Neighbors for current. FCOST:  469
# Neighbors for current. FCOST:  470
# Neighbors for current. FCOST:  470
# Neighbors for current. FCOST:  471
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  471
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  471
# Neighbors for current. FCOST:  471
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  471
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  473
# Neighbors for current. FCOST:  476
# Neighbors for current. FCOST:  476
# Neighbors for current. FCOST:  476
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  477
# Neighbors for current. FCOST:  477
# Neighbors for current. FCOST:  475
# Neighbors for current. FCOST:  480
# Neighbors for current. FCOST:  480
# Neighbors for current. FCOST:  480
# Neighbors for current. FCOST:  480
# Neighbors for current. FCOST:  482
# Neighbors for current. FCOST:  480
# Neighbors for current. FCOST:  482
# Neighbors for current. FCOST:  484
# Neighbors for current. FCOST:  482
# Neighbors for current. FCOST:  482
# Neighbors for current. FCOST:  484
# Neighbors for current. FCOST:  482
# Neighbors for current. FCOST:  484
# Neighbors for current. FCOST:  484
# Neighbors for current. FCOST:  484
# Neighbors for current. FCOST:  486
# Neighbors for current. FCOST:  487
# Neighbors for current. FCOST:  487
# Neighbors for current. FCOST:  487
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  491
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  491
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  489
# Neighbors for current. FCOST:  491
# Neighbors for current. FCOST:  493
# Neighbors for current. FCOST:  491
# Neighbors for current. FCOST:  493
# Neighbors for current. FCOST:  493
# Neighbors for current. FCOST:  493
# Neighbors for current. FCOST:  495
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  500
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  500
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  500
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  500
# Neighbors for current. FCOST:  498
# Neighbors for current. FCOST:  502
# Neighbors for current. FCOST:  504
# Neighbors for current. FCOST:  502
# Neighbors for current. FCOST:  504
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  509
# Neighbors for current. FCOST:  509
# Neighbors for current. FCOST:  509
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  509
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  507
# Neighbors for current. FCOST:  509
# Neighbors for current. FCOST:  509
# Neighbors for current. FCOST:  511
# Neighbors for current. FCOST:  511
# Neighbors for current. FCOST:  511
# Neighbors for current. FCOST:  513
# Neighbors for current. FCOST:  511
# Neighbors for current. FCOST:  513
# Neighbors for current. FCOST:  515
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  518
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  518
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  518
# Neighbors for current. FCOST:  516
# Neighbors for current. FCOST:  520
# Neighbors for current. FCOST:  520
# Neighbors for current. FCOST:  520
# Neighbors for current. FCOST:  520
# Neighbors for current. FCOST:  522
# Neighbors for current. FCOST:  522
# Neighbors for current. FCOST:  524
# Neighbors for current. FCOST:  526
# Neighbors for current. FCOST:  526
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  527
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  525
# Neighbors for current. FCOST:  527
# Neighbors for current. FCOST:  527
# Neighbors for current. FCOST:  529
# Neighbors for current. FCOST:  529
# Neighbors for current. FCOST:  531
# Neighbors for current. FCOST:  529
# Neighbors for current. FCOST:  531
# Neighbors for current. FCOST:  533
# Neighbors for current. FCOST:  535
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  536
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  536
# Neighbors for current. FCOST:  534
# Neighbors for current. FCOST:  536
# Neighbors for current. FCOST:  537
# Neighbors for current. FCOST:  537
# Neighbors for current. FCOST:  537
# Neighbors for current. FCOST:  538
# Neighbors for current. FCOST:  538
# Neighbors for current. FCOST:  540
# Neighbors for current. FCOST:  538
# Neighbors for current. FCOST:  540
# Neighbors for current. FCOST:  540
# Neighbors for current. FCOST:  542
# Neighbors for current. FCOST:  544
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  545
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  545
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  545
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  543
# Neighbors for current. FCOST:  546
# Neighbors for current. FCOST:  547
# Neighbors for current. FCOST:  547
# Neighbors for current. FCOST:  548
# Neighbors for current. FCOST:  548
# Neighbors for current. FCOST:  548
# Neighbors for current. FCOST:  547
# Neighbors for current. FCOST:  549
# Neighbors for current. FCOST:  549
# Neighbors for current. FCOST:  549
# Neighbors for current. FCOST:  551
# Neighbors for current. FCOST:  553
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  554
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  554
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  554
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  552
# Neighbors for current. FCOST:  555
# Neighbors for current. FCOST:  556
# Neighbors for current. FCOST:  556
# Neighbors for current. FCOST:  556
# Neighbors for current. FCOST:  557
# Neighbors for current. FCOST:  558
# Neighbors for current. FCOST:  558
# Neighbors for current. FCOST:  559
# Neighbors for current. FCOST:  559
# Neighbors for current. FCOST:  559
# Neighbors for current. FCOST:  559
# Neighbors for current. FCOST:  560
# Neighbors for current. FCOST:  560
# Neighbors for current. FCOST:  562
# Neighbors for current. FCOST:  561
# Neighbors for current. FCOST:  563
# Neighbors for current. FCOST:  561
# Neighbors for current. FCOST:  561
# Neighbors for current. FCOST:  561
# Neighbors for current. FCOST:  563
# Neighbors for current. FCOST:  561
# Neighbors for current. FCOST:  561
# Neighbors for current. FCOST:  563
# Neighbors for current. FCOST:  564
# Neighbors for current. FCOST:  565
# Neighbors for current. FCOST:  565
# Neighbors for current. FCOST:  566
# Neighbors for current. FCOST:  567
# Neighbors for current. FCOST:  567
# Neighbors for current. FCOST:  568
# Neighbors for current. FCOST:  569
# Neighbors for current. FCOST:  570
# Neighbors for current. FCOST:  570
# Neighbors for current. FCOST:  570
# Neighbors for current. FCOST:  570
# Neighbors for current. FCOST:  570
# Neighbors for current. FCOST:  571
# Neighbors for current. FCOST:  570
# Neighbors for current. FCOST:  572
# Neighbors for current. FCOST:  572
# Neighbors for current. FCOST:  572
# Neighbors for current. FCOST:  573
# Neighbors for current. FCOST:  574
# Neighbors for current. FCOST:  574
# Neighbors for current. FCOST:  575
# Neighbors for current. FCOST:  576
# Neighbors for current. FCOST:  576
# Neighbors for current. FCOST:  577
# Neighbors for current. FCOST:  578
# Neighbors for current. FCOST:  578
# Neighbors for current. FCOST:  579
# Neighbors for current. FCOST:  580
# Neighbors for current. FCOST:  581
# FOUND YOU
